# %%
import numpy as np

# %% [markdown]
# # 面向数组进行数组编程
#
# 使用Numpy

# %%
# meshgrid 函数接受两个一维数组，并根据两个数组所有的x， y 生成一个二维矩阵
points = np.arange(-5, 5, 0.01)

# %%
xs, ys = np.meshgrid(points, points)

# %%
ys
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
xs
# Out:
# array([[-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        ...,
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99]])

# %%
z = np.sqrt(xs ** 2 + ys ** 2)

# %%
z
# Out:
# array([[7.07106781, 7.06400028, 7.05693985, ..., 7.04988652, 7.05693985,
#         7.06400028],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        ...,
#        [7.04988652, 7.04279774, 7.03571603, ..., 7.0286414 , 7.03571603,
#         7.04279774],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568]])

# %%
import matplotlib.pyplot as plt

# %%
# gray 找不到引用，但是有？？？
plt.imshow(z, cmap=plt.cm.gray);plt.colorbar()

# %%
plt.title("Image plot of $\\sqrt{x * 2 + y ^ 2}$ for a grid of values")
# Out:
# Text(0.5, 1.0, 'Image plot of $\\sqrt{x * 2 + y ^ 2}$ for a grid of values')

# %% [markdown]
# # 条件逻辑作为数组操作

# %%
xarr = np.array([1.1, 1.2, 1.3, 1.4, 1.5])

# %%
yarr = np.array([2.1, 2.2, 2.3, 2.4, 2.5])

# %%
cond = np.array([True, False, True, True, False])

# %%
result = [(x if c else y) for x, y, c in zip(xarr, yarr, cond)]

# %%
result
# Out:
# [1.1, 2.2, 1.3, 1.4, 2.5]

# %%
result = np.where(cond, xarr, yarr)

# %%
result
# Out:
# array([1.1, 2.2, 1.3, 1.4, 2.5])

# %%
arr = np.random.randn(4, 4)

# %%
arr
# Out:
# array([[-0.69399596,  0.00245543, -1.27566771, -2.4097629 ],
#        [-0.35729893, -0.14966165,  2.29296328,  0.1134548 ],
#        [ 0.59110597,  0.12391005, -1.35793928, -1.11426879],
#        [ 1.6016801 ,  0.22822669,  0.97251046,  0.11939585]])

# %%
arr > 0
# Out:
# array([[False,  True, False, False],
#        [False, False,  True,  True],
#        [ True,  True, False, False],
#        [ True,  True,  True,  True]])

# %%
np.where(arr > 0, 2, -2)
# Out:
# array([[-2,  2, -2, -2],
#        [-2, -2,  2,  2],
#        [ 2,  2, -2, -2],
#        [ 2,  2,  2,  2]])

# %%
np.where(arr > 0, 2, arr)
# Out:
# array([[-0.69399596,  2.        , -1.27566771, -2.4097629 ],
#        [-0.35729893, -0.14966165,  2.        ,  2.        ],
#        [ 2.        ,  2.        , -1.35793928, -1.11426879],
#        [ 2.        ,  2.        ,  2.        ,  2.        ]])

# %% [markdown]
# # 数学和统计方法

# %%
# 正态随机分布
arr = np.random.randn(5, 4)

# %%
arr
# Out:
# array([[-0.8895838 ,  0.89676988,  0.97062591,  0.81427548],
#        [ 1.1266264 , -0.65008496, -0.57174885, -2.07008411],
#        [ 1.3913241 ,  0.535251  , -0.29686002,  0.23897489],
#        [-0.480187  , -1.39136372, -0.96936961, -0.40280202],
#        [ 1.66399385,  0.67970185, -0.39365445, -1.03287052]])

# %% [raw]
# 聚合函数
# sum 总和
# mean
# std 标准差

# %%
arr.mean()
# Out:
# -0.0415532851462941

# %%
np.mean(arr)
# Out:
# -0.0415532851462941

# %%
arr.sum()
# Out:
# -0.8310657029258819

# %%
arr
# Out:
# array([[-0.8895838 ,  0.89676988,  0.97062591,  0.81427548],
#        [ 1.1266264 , -0.65008496, -0.57174885, -2.07008411],
#        [ 1.3913241 ,  0.535251  , -0.29686002,  0.23897489],
#        [-0.480187  , -1.39136372, -0.96936961, -0.40280202],
#        [ 1.66399385,  0.67970185, -0.39365445, -1.03287052]])

# %%
arr.std()
# Out:
# 0.9889082350539973

# %% [markdown]
# 可以接收一个axis的参数，用于计算给定轴上的统计值，形成一个下降一维度的数组
#
# 0, 行
# 1，列
# 3，第三轴，三维
# 4，第四轴，四维

# %%
arr.mean(axis=1)
# Out:
# array([ 0.44802187, -0.54132288,  0.46717249, -0.81093059,  0.22929268])

# %%
arr.sum(axis=0)
# Out:
# array([ 2.81217355,  0.07027405, -1.26100702, -2.45250629])

# %%
arr = np.array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
arr.cumsum()
# Out:
# array([ 0,  1,  3,  6, 10, 15, 21, 28])
